# %%
from bs4 import BeautifulSoup 
import requests 
import csv
import pandas as pd

# %%
descriptions = [] # Create a list to store the descriptions
processors=[]
ram=[]
os=[]
storage=[]
inches=[]
warranty=[]
prices = []
ratings = []

# %%
pages = list(range(1,21))
for page in pages:
  req = requests.get("https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(page)).text  # URL of the website which you want to scrape
  #content = req.content # Get the content
  soup = BeautifulSoup(req,'html.parser')
  #print(soup.prettify())

  desc = soup.find_all('div' , class_='_3wU53n')
  for i in range(len(desc)):
      descriptions.append(desc[i].text)
  len(descriptions)

  commonclass = soup.find_all('li',class_='tVe95H') # We observe that the classnames for the different specifications are under one div.So we need to apply some method to extract the different features.
  # Create empty lists for the features
  for i in range(0,len(commonclass)):
    p=commonclass[i].text # Extracting the text from the tags
    if("Core" in p): 
        processors.append(p)
    elif("RAM" in p): 
        ram.append(p)
    elif("HDD" in p or "SSD" in p):
        storage.append(p)
    elif("Operating" in p):
        os.append(p)
    elif("Display" in p):
        inches.append(p)
    elif("Warranty" in p):
        warranty.append(p)

  price = soup.find_all('div',class_='_1vC4OE _2rQ-NK') 
  # Extracting price of each laptop from the website
  for i in range(len(price)):
    prices.append(price[i].text)
    len(prices)

  rating = soup.find_all('div',class_='hGSR34') 
  #Extracting the ratings of each laptop from the website
  for i in range(len(rating)):
    ratings.append(rating[i].text)
    len(ratings)

# %%
print(len(descriptions))
print(len(processors))
print(len(ram))
print(len(os))
print(len(storage))
print(len(warranty))
print(len(inches))
print(len(prices))
print(len(ratings))
# Out:
# 456
# 456
# 458
# 472
# 460
# 440
# 469
# 456
# 574

# %%
df = {'Description':descriptions[440],'Processor':processors[440],'RAM':ram[440],'Operating System':os[slice(440)],'Storage':storage[slice(440)],'Display':inches[slice(440)],'Warranty':warranty[slice(440)],'Price':prices[slice(440)]}
dataset = pd.DataFrame(data = df) # Finally merging all the features into a single dataframe

# %%
dataset
# Out:
#                                            Description  ...      Price
# 0    Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹35,990
# 1    Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹79,990
# 2    Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...  ₹1,19,990
# 3    Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹29,625
# 4    Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹38,990
# ..                                                 ...  ...        ...
# 435  Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹29,625
# 436  Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹81,989
# 437  Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹41,990
# 438  Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹95,695
# 439  Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...  ...    ₹39,203
#
# [440 rows x 8 columns]

# %%
dataset.to_csv('laptops20.csv')

# %%
df = pd.read_csv('laptops20.csv')
df.shape
# Out:
# (440, 9)

# %%
import sqlite3

# %%
conn = sqlite3.connect('TestDB1.db')
c = conn.cursor()

# %%
c.execute('CREATE TABLE IF NOT EXISTS laptop20 (Laptop_Id, Description, Processor, RAM, Operating System, Storage, Display, Warranty, Price)')
conn.commit()

# %%
df.to_sql('laptop20', conn, if_exists='replace', index = False)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
c.execute('''SELECT * FROM laptop20''')

# %%
for row in c.fetchall():
    print(row)
# Out:
# (0, 'Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX331UAL-EG031T Thin and Light Lap...', 'Intel Core i7 Processor (8th Gen)', '8 GB DDR4 RAM', '64 bit Windows 10 Operating System', '256 GB SSD', '35.56 cm (14 inch) Display', '1 Year Limited Hardware Warranty, In Home Service After Remote Diagnosis - Retail', '₹35,990')
# (1, 'Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX331UAL-EG031T Thin and Light Lap...', 'Intel Core i7 Processor (8th Gen)', '8 GB DDR4 RAM', '64 bit Windows 10 Operating System', '1 TB HDD|256 GB SSD', '35.56 cm (14 inch) Touchscreen Display', '1 Year Onsite Warranty', '₹79,990')
# (2, 'Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX331UAL-EG031T Thin and Light Lap...', 'Intel Core i7 Processor (8th Gen)', '8 GB DDR4 RAM', '64 bit Windows 10 Operating System', '1 TB HDD|256 GB SSD', '39.62 cm (15.6 inch) Display', '2 Year Warranty', '₹1,19,990')
# ...

# %%
c.execute('''  
SELECT RAM, Display, Price FROM laptop20 limit 5
          ''')

# %%
for row in c.fetchall():
    print(row)
# Out:
# ('8 GB DDR4 RAM', '35.56 cm (14 inch) Display', '₹35,990')
# ('8 GB DDR4 RAM', '35.56 cm (14 inch) Touchscreen Display', '₹79,990')
# ('8 GB DDR4 RAM', '39.62 cm (15.6 inch) Display', '₹1,19,990')
# ('8 GB DDR4 RAM', 'Matrix Display, Dragon Center, Cooler Boost 5, True Color 2.0, Nahimic 3', '₹29,625')
# ('8 GB DDR4 RAM', '39.62 cm (15.6 inch) Display', '₹38,990')
